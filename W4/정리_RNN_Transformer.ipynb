# %% [markdown]
# ## RNN
#
# - Sigmoid: info gets squashed. Vanishing gradient.
# - ReLU: info gets multiplied. Exploding gradient.
#
# ![scrsht%202022-02-09%20at%2013.56.04.png](attachment:scrsht%202022-02-09%20at%2013.56.04.png)

# %% [markdown]
# ## LSTM
#
# - Long term dependency
# - Cell state
# - 3 gates
#
# ![scrsht%202022-02-09%20at%2014.06.43.png](attachment:scrsht%202022-02-09%20at%2014.06.43.png)

# %% [markdown]
# ## GRU
#
# - LSTM with 3 gates has too many parameters
# - 2 gates

# %% [markdown]
# # Transformer

# %% [markdown]
# ## Encoder

# %% [markdown]
# ![scrsht%202022-02-09%20at%2014.17.48.png](attachment:scrsht%202022-02-09%20at%2014.17.48.png)

# %% [markdown]
# ![scrsht%202022-02-09%20at%2014.18.00.png](attachment:scrsht%202022-02-09%20at%2014.18.00.png)

# %% [markdown]
# ### Scaled Dot-Product Attention
#
# ![scrsht%202022-02-09%20at%2014.18.26.png](attachment:scrsht%202022-02-09%20at%2014.18.26.png)

# %% [markdown]
# From `x` to `z`, with using `q`, `k`, `v`
#
# Attention = `softmax(dot(q,k)/scale)` = weight of `v`
#
# `dot()` is implemented with `matmul()`
#
# ![scrsht%202022-02-09%20at%2014.38.25-3.png](attachment:scrsht%202022-02-09%20at%2014.38.25-3.png)

# %% [markdown]
# ![scrsht%202022-02-09%20at%2014.18.40.png](attachment:scrsht%202022-02-09%20at%2014.18.40.png)
#
# 2 by 4 matrix. There are 2 words and each word is expressed in a 4D vector.

# %% [markdown]
# ### Multi-Head Attention
#
# ![scrsht%202022-02-09%20at%2014.19.13.png](attachment:scrsht%202022-02-09%20at%2014.19.13.png)
#
# 하나의 입력에 대해서 `q`, `k`, `v`를 여러개 만듦

# %% [markdown]
# ### Positional encoding
#
# ![scrsht%202022-02-09%20at%2014.20.03.png](attachment:scrsht%202022-02-09%20at%2014.20.03.png)

# %% [markdown]
# ## Decoder

# %% [markdown]
# Topmost encoder transfers `k`, `v` to decoders
#
# ![scrsht%202022-02-09%20at%2014.20.38.png](attachment:scrsht%202022-02-09%20at%2014.20.38.png)
