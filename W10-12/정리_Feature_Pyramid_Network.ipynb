# %% [markdown]
# # FPN - Feature Pyramid Network

# %% [markdown]
# ### Neck
#
# - 최종 feature map만 사용하면 작은 객체를 포착하기 어려움
# - Neck 이용하면 다양한 크기의 객체 잘 탐지 가능
# - Neck을 이용해서 low level과 high level의 feature map을 섞어줌 (Top-down Pathway)
#
# ![scrsht%202022-03-22%20at%2016.10.33.png](attachment:scrsht%202022-03-22%20at%2016.10.33.png)

# %% [markdown]
# # PANet - Path Aggregation Network

# %% [markdown]
# ### Bottom-up Path Augmentation
#
# bottom-up 방향으로도 feature map을 섞어줌
#
# ![scrsht%202022-03-22%20at%2016.11.31.png](attachment:scrsht%202022-03-22%20at%2016.11.31.png)

# %% [markdown]
# ### Adaptive Feature Pooling
#
# 모든 stage에서 ROI를 뽑아내고 나중에 합침
#
# ![scrsht%202022-03-22%20at%2016.12.57.png](attachment:scrsht%202022-03-22%20at%2016.12.57.png)

# %% [markdown]
# # Post FPN

# %% [markdown]
# ### Recursive Feature Pyramid (from DetectoRS)
#
# ![scrsht%202022-03-22%20at%2016.13.57.png](attachment:scrsht%202022-03-22%20at%2016.13.57.png)

# %% [markdown]
# ### BiFPN - Bi-directional FPN
#
# ![scrsht%202022-03-22%20at%2016.15.09.png](attachment:scrsht%202022-03-22%20at%2016.15.09.png)

# %% [markdown]
# ### NASFPN - Neural Architecture Search FPN
#
# - COCO dataset, ResNet 기준의 architecture라서 범용적이지 못함
#
# ![scrsht%202022-03-22%20at%2016.15.38.png](attachment:scrsht%202022-03-22%20at%2016.15.38.png)

# %% [markdown]
# ### AugFPN
#
# - Residual Feature Augmentation
# - Soft ROI Selection
#   - PANet처럼 모든 feature map 사용
#   - 하지만 PANet처럼 max pooling하는게 아니라 학습가능한 channel-wise weight 사용
